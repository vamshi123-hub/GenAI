# %%
from langchain_community.embeddings import OllamaEmbeddings
embeddings = (OllamaEmbeddings(model = "gemma2:2b"))
embeddings
# Out:
# OllamaEmbeddings(base_url='http://localhost:11434', model='gemma2:2b', embed_instruction='passage: ', query_instruction='query: ', mirostat=None, mirostat_eta=None, mirostat_tau=None, num_ctx=None, num_gpu=None, num_thread=None, repeat_last_n=None, repeat_penalty=None, temperature=None, stop=None, tfs_z=None, top_k=None, top_p=None, show_progress=False, headers=None, model_kwargs=None)

# %%
r1 = embeddings.embed_documents([
    "Alpha is the first letter of greek alphsbet",
    "beta is the second letter of greek alphsbet",
])
r1
# Out:
# [[-0.4085182547569275,
#   -0.4985080659389496,
#   -0.9984117746353149,
#   0.7224025130271912,
#   0.653750479221344,
#   -0.8462002873420715,
#   1.765594482421875,
#   -1.341964602470398,
#   -1.0001786947250366,
#   0.4366726279258728,
#   -1.8377529382705688,
#   -0.7539114952087402,
#   -0.24988792836666107,
#   -0.5427902936935425,
#   0.28449752926826477,
#   -1.459739327430725,
#   -4.439545154571533,
#   -1.7833770513534546,
#   -2.8893821239471436,
#   -1.1798856258392334,
#   1.1179473400115967,
#   1.3755837678909302,
#   -1.4677883386611938,
#   0.03058621473610401,
#   3.4903359413146973,
#   -0.3045388460159302,
#   0.7770155668258667,
#   -0.19408175349235535,
#   -0.31079912185668945,
#   1.250857949256897,
#   -0.8019082546234131,
#   0.545198917388916,
#   -2.3787291049957275,
#   -1.4615974426269531,
#   -0.3305010199546814,
#   0.38349148631095886,
#   -1.0882495641708374,
#   0.650961697101593,
#   0.5185502171516418,
#   -2.848149538040161,
# ...

# %%
len(r1)
# Out:
# 2

# %%
r1[0]
# Out:
# [-0.4085182547569275,
#  -0.4985080659389496,
#  -0.9984117746353149,
#  0.7224025130271912,
#  0.653750479221344,
#  -0.8462002873420715,
#  1.765594482421875,
#  -1.341964602470398,
#  -1.0001786947250366,
#  0.4366726279258728,
#  -1.8377529382705688,
#  -0.7539114952087402,
#  -0.24988792836666107,
#  -0.5427902936935425,
#  0.28449752926826477,
#  -1.459739327430725,
#  -4.439545154571533,
#  -1.7833770513534546,
#  -2.8893821239471436,
#  -1.1798856258392334,
#  1.1179473400115967,
#  1.3755837678909302,
#  -1.4677883386611938,
#  0.03058621473610401,
#  3.4903359413146973,
#  -0.3045388460159302,
#  0.7770155668258667,
#  -0.19408175349235535,
#  -0.31079912185668945,
#  1.250857949256897,
#  -0.8019082546234131,
#  0.545198917388916,
#  -2.3787291049957275,
#  -1.4615974426269531,
#  -0.3305010199546814,
#  0.38349148631095886,
#  -1.0882495641708374,
#  0.650961697101593,
#  0.5185502171516418,
#  -2.848149538040161,
#  0.3637623190879822,
#  2.948899269104004,
# ...

# %%
len(r1[0])
# Out:
# 2304

# %%
embeddings.embed_query("what is the first letter of greek alphabet")
# Out:
# [-0.7254127860069275,
#  -0.9567466974258423,
#  -2.250277042388916,
#  0.27991983294487,
#  0.7322763800621033,
#  1.3823349475860596,
#  0.8973339200019836,
#  -0.1421951949596405,
#  -0.40480199456214905,
#  0.6220415234565735,
#  -3.0747663974761963,
#  -0.507914125919342,
#  -1.5760971307754517,
#  -1.1814863681793213,
#  -0.17004217207431793,
#  -0.7386835813522339,
#  -3.1980104446411133,
#  -1.2475183010101318,
#  -4.707422256469727,
#  -0.5564828515052795,
#  1.8691797256469727,
#  2.943530797958374,
#  -2.255622625350952,
#  -1.4608573913574219,
#  3.2599990367889404,
#  -1.8375771045684814,
#  1.0038877725601196,
#  0.8164907097816467,
#  0.4966273605823517,
#  -0.16097000241279602,
#  -2.70702862739563,
#  1.2360742092132568,
#  -0.47184890508651733,
#  -2.2100889682769775,
#  0.7236055135726929,
#  1.672088384628296,
#  -1.6855976581573486,
#  1.7209893465042114,
#  0.9474098682403564,
#  -1.722142219543457,
#  -0.4981028139591217,
#  2.9079718589782715,
# ...

# %% [markdown]
# Other Embedding Model
# ##https://github.com/ollama/ollama
# ##https://ollama.com/library/mxbai-embed-large

# %%
embeddings = OllamaEmbeddings(model = "mxbai-embed-large")
text = "This is the OllamaEmbeddings"
query_res = embeddings.embed_query(text)
query_res
# Out:
# [0.29844292998313904,
#  -0.5016227960586548,
#  -0.07072155922651291,
#  0.3030660152435303,
#  -0.25728878378868103,
#  -0.039185285568237305,
#  0.4997190833091736,
#  0.3077884018421173,
#  0.6496947407722473,
#  0.6649534106254578,
#  0.042099516838788986,
#  0.35020312666893005,
#  -0.3885851204395294,
#  -0.06776585429906845,
#  -1.5653557777404785,
#  0.2745814621448517,
#  -0.35317888855934143,
#  0.4268287122249603,
#  -0.22383040189743042,
#  0.010516010224819183,
#  0.15170511603355408,
#  0.672317385673523,
#  -1.435821771621704,
#  -0.21265378594398499,
#  0.02366972714662552,
#  0.0701385959982872,
#  -0.25856250524520874,
#  -0.3383394181728363,
#  0.7550230622291565,
#  1.2862110137939453,
#  -0.13453838229179382,
#  0.3627691864967346,
#  -0.4030350148677826,
#  -0.03928329050540924,
#  0.027296211570501328,
#  -0.2824694514274597,
#  0.8200536966323853,
#  -0.661573052406311,
#  0.038589637726545334,
#  -1.3491638898849487,
#  -0.00792576465755701,
# ...

# %%
query_res[0]
# Out:
# 0.29844292998313904

# %%
len(query_res)
# Out:
# 1024
